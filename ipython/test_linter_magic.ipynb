# %%
# %reload_ext linter_magic
def foo():
    pass

a = [1, 2, 3]
b = 2
# %linter_data b
# Out:
# LINE: b
# Parsed line: Namespace(data='b', data_header=None, data_delim=None, show_stats=None, show_na=None, show_passing=None)
# {'b': 2}

# %%
# %%lint_cell data=a
# foo()
# Out:
# ('data=a', 'foo()\n')
